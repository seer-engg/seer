# %%
import sys
import os
parent_dir = os.path.dirname(os.getcwd())
import sys
sys.path.append(parent_dir)

# %%
from sandbox import prepare_target_agent

sbx, url = await prepare_target_agent(repo_url="https://github.com/seer-engg/buggy-coder", setup_script='pip install -e .', timeout=300)
# Out:
# 2025-11-01 20:31:16 | sandbox.initialize | INFO | Creating E2B sandbox for codex...
# 2025-11-01 20:31:17 | sandbox.initialize | INFO | Sandbox created: iw0xzbghu0nodmet55tdi
# 2025-11-01 20:31:17 | sandbox.initialize | INFO | Cloning/updating repository inside sandbox (shell)...
# 2025-11-01 20:32:00 | sandbox.initialize | INFO | Setup project: Obtaining file:///home/user/buggy-coder
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...

# %%
 sbx.sandbox_id
# Out:
# 'iw0xzbghu0nodmet55tdi'
